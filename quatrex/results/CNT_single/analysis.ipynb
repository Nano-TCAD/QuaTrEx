# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors as colors
import matplotlib.ticker as ticker

import gif

# %%
DOS_TEST = np.loadtxt('DOS_.dat').view(complex)

# %%
plt.pcolormesh(DOS_TEST.real)
