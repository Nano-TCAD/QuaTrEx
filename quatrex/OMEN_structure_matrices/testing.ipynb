# %%
import numpy as np
from OMENHamClass import Hamiltonian
file_hm = '/usr/scratch/mont-fort17/dleonard/GW_paper/Si_Nanowire/'
no_orb = np.array([1,4])
Nk = np.array([1,1,1])
ham_obj = Hamiltonian(file_hm, no_orb, Nk)

# %%
ham_obj.Hamiltonian['H_4'].toarray()
# Out:
# array([[-6.222343+0.j, -0.019496+0.j, -0.008012+0.j, ...,  0.      +0.j,
#          0.      +0.j,  0.      +0.j],
#        [-0.019496+0.j, -6.22247 +0.j,  0.070472+0.j, ...,  0.      +0.j,
#          0.      +0.j,  0.      +0.j],
#        [-0.008012+0.j,  0.070472+0.j, -5.683315+0.j, ...,  0.      +0.j,
#          0.      +0.j,  0.      +0.j],
#        ...,
#        [ 0.      +0.j,  0.      +0.j,  0.      +0.j, ..., -6.173997+0.j,
#         -0.007566+0.j,  0.008729+0.j],
#        [ 0.      +0.j,  0.      +0.j,  0.      +0.j, ..., -0.007566+0.j,
#         -6.173982+0.j, -0.015942+0.j],
#        [ 0.      +0.j,  0.      +0.j,  0.      +0.j, ...,  0.008729+0.j,
#         -0.015942+0.j, -6.168942+0.j]])

# %%
import quatrex.utilities as ut
import sys
import numpy as np
print(sys.path)

help(ut)
# Out:
# ['/home/awinka/Python/my_QuaTrEx/quatrex/OMEN_structure_matrices', '/home/awinka/.conda/envs/quatrex/lib/python311.zip', '/home/awinka/.conda/envs/quatrex/lib/python3.11', '/home/awinka/.conda/envs/quatrex/lib/python3.11/lib-dynload', '', '/home/awinka/.conda/envs/quatrex/lib/python3.11/site-packages']
# Help on package quatrex.utilities in quatrex:
#
# NAME
#     quatrex.utilities - # Copyright 2023 ETH Zurich and the QuaTrEx authors. All rights reserved.
#
# PACKAGE CONTENTS
#     block_extraction
#     bsr
#     change_format
#     change_format_gpu
#     hilbert
#     linalg_cpu
#     linalg_gpu
#     matrix_creation
#     matrix_creation_gpu
#     read_utils
#     test_dos_com
#     utils_gpu
#
# FILE
#     /home/awinka/Python/my_QuaTrEx/quatrex/utilities/__init__.py
