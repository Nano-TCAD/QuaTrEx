# %%
import numpy as np
from quatrex.OMEN_structure_matrices.OMENHamClass_mod import Matrices
matrix_path = "/usr/scratch/bucaramanga/awinka/MoS2/MoS2_matrices/quatrex_inputs/"
Vappl = 0.0  # 0.2  # Applied voltage
num_kpoints = np.array([1, 5, 1])
matrix_obj = Matrices(matrix_path, num_kpoints, Vappl=Vappl, potential_type="none")
rows = matrix_obj.rows
columns = matrix_obj.columns
vh1D_k = np.asarray([mat[rows, columns] for mat in matrix_obj.k_Coulomb_matrix.values()]).squeeze(axis=1)

# %%
vh1D_k.shape
# Out:
# (5, 131410)
